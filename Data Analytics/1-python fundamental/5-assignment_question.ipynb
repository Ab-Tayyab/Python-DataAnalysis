# %% [markdown]
# Python Basics

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
name = input("Enter name")
print(name)
# Out:
# Abdullah

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = 10
if num>0:
    print("Positive")
elif num<0:
    print("Negative")
else:
    print("Number is zero")
# Out:
# Positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
n1 = float(input("Enter first number"))
n2 = float(input("Enter second number"))
n3 = float(input("Enter third number"))
if n1>n2 and n1>n3:
    largest = n1
elif n2>n1 and n2>n3:
    largest = n2
else:
    largest = n3

print("Largest number is: ",largest)
# Out:
# Largest number is:  23.0

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num = int(input("Enter number"))
fac=1
for i in range(1,num+1):
    fac *=i
print(f"Factorial of {num} is {fac}")
# Out:
# Factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
dtype1 = 10
print(type(dtype1),dtype1)
dtype2 = 4.3
print(type(dtype2),dtype2)
dtype3 = "string"
print(type(dtype3),dtype3)
dtype4 = True
print(type(dtype4),dtype4)
# Out:
# <class 'int'> 10
# <class 'float'> 4.3
# <class 'str'> string
# <class 'bool'> True

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
v1 = 10
v2 = 20
print(f"Before swapping v1 is {v1} and v2 is {v2}")
v1,v2 = v2,v1
print(f"After swapping v1 is {v1} and v2 is {v2}")
# Out:
# Before swapping v1 is 10 and v2 is 20
# After swapping v1 is 20 and v2 is 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
temp = int(input("Enter temperature in Celsius"))
fahr = ((9/5)*temp) + 32
print(f"Celsius {temp} is equal to fahrenheit {fahr}")
# Out:
# Celsius 40 is equal to fahrenheit 104.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "Abdullah"
str2 = "Tayyab"
print(f"{str1} {str2}")
print(str1 + " " + str2)
# Out:
# Abdullah Tayyab
# Abdullah Tayyab

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
num = "Abdullah Tayyab"
if isinstance(num, str):
    print("Its a string")
else:
    print("Not a string")
# Out:
# Its a string

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
v1 = 30
v2 = 10
print(f"{v1} + {v2} = {v1+v2}")
print(f"{v1} - {v2} = {v1-v2}")
print(f"{v1} * {v2} = {v1*v2}")
print(f"{v1} / {v2} = {v1/v2}")
# Out:
# 30 + 10 = 40
# 30 - 10 = 20
# 30 * 10 = 300
# 30 / 10 = 3.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
v1 = 10
v2 = 5
print(f"{v1} == {v2} = {v1==v2}")
print(f"{v1} != {v2} = {v1!=v2}")
print(f"{v1} > {v2} = {v1>v2}")
print(f"{v1} < {v2} = {v1<v2}")
# Out:
# 10 == 5 = False
# 10 != 5 = True
# 10 > 5 = True
# 10 < 5 = False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
v1 = True
v2 = False
print(f"{v1} and {v2} = {v1 and v2}")
print(f"{v1} or {v2} = {v1 or v2}")
print(f"not {v1} = {not v1}")
# Out:
# True and False = False
# True or False = True
# not True = False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = int(input("Enter number"))
print(f"Square of {num} is {num*num}")
# or 
print(f"Square of {num} is {num**2}")
# Out:
# Square of 9 is 81
# Square of 9 is 81

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter number"))
if num%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
naturalNumber = int(input("Enter number"))
sum = 0
for i in range(1,naturalNumber+1):
    sum +=i
print(sum)

# or 

sum = (naturalNumber*(naturalNumber+1))//2
print(sum)
# Out:
# 5050
# 5050

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter year"))
if (year%4==0 and year%100!=0) or year%400==0:
    print("Leap Year ",year)
else:
    print("Not a leap Year ",year)
# Out:
# Leap Year  2000

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str1 = "Abdullah"
revStr = str1[::-1]
print("Original String is = ",str1)
print("Reverse String is = ",revStr)
# Out:
# Original String is =  Abdullah
# Reverse String is =  halludbA

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
str1 = input("Enter String")
if str1 == str1[::-1]:
    print("Palindrome String")
else:
    print("Not a palindrome String")
# Out:
# Not a palindrome String

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
li = [2,1,3,4,2,3,5,0]
li.sort()
print(li)

li2 = [int(x) for x in input("Enter number seperated by space").split()]
li2.sort()
print(li2)
# Out:
# [0, 1, 2, 2, 3, 3, 4, 5]
# [0, 1, 2, 3, 3, 4, 5, 6, 8]
