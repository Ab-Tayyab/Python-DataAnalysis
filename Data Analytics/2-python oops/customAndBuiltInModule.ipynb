# %%
import myModule
myModule.greet("Abdullah Tayyab")
# Out:
# Hi!  Abdullah Tayyab

# %%
import myModule
myModule.sqrt(81)
# Out:
# Sqrt is:  9

# %%
import math
print(math.sqrt(81))

# or 
from math import sqrt
print(sqrt(90))
# Out:
# 9.0
# 9.486832980505138
