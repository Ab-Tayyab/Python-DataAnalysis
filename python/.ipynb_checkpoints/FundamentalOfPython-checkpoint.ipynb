# %%
name = "Abdullah"
age = 28
designation = "Data Analyst"
print("I'm ",name,", my age is ",age," and my designation is ",designation)
# Out:
# I'm  Abdullah , my age is  28  and my designation is  Data Analyst
