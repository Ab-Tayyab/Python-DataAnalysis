# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ab tayyab\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ab tayyab\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ab tayyab\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ab tayyab\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ab tayyab\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ab tayyab\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

# %%
# series
s = pd.Series([10,20,30,40,50],index=['a','b','c','d','e'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
print("Values",s.values)
print("Index",s.index)
print("Dtype",s.dtype)
# Out:
# Values [10 20 30 40 50]
# Index Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# Dtype int64

# %%
print(s.head)
print(s.tail)
print(s.value_counts())
# Out:
# <bound method NDFrame.head of a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64>
# <bound method NDFrame.tail of a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64>
# 10    1
# 20    1
# 30    1
# 40    1
# 50    1
# Name: count, dtype: int64

# %%
# DataFrames, data in 2D labled data structure and store different type data
data={
    'Name':['Alice','Bob','Chalie'],
    'Age':[25,30,22],
    'City':['New York','Paris','London']
}
df= pd.DataFrame(data)
print(df)
# Out:
#      Name  Age      City
# 0   Alice   25  New York
# 1     Bob   30     Paris
# 2  Chalie   22    London

# %%
# Load sample .csv file
df = pd.read_csv('./files/retail_sales.csv')
#Inspect DataFarmes
print("Info: \n",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1825 non-null   object
#  1   Category  1821 non-null   object
#  2   Sales     1823 non-null   float64
#  3   Quantity  1820 non-null   float64
#  4   Profit    1825 non-null   float64
#  5   Region    1820 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 85.7+ KB
# Info
#  None

# %%
print("\nShape:", df.shape)
print("\nData Types:", df.dtypes)
# Out:
# Shape: (1825, 6)
#
# Data Types: Date         object
# Category     object
# Sales       float64
# Quantity    float64
# Profit      float64
# Region       object
# dtype: object

# %%
print("\nStatistical Summary:\n", df.describe())
# Out:
# Statistical Summary:
#               Sales     Quantity       Profit
# count  1823.000000  1820.000000  1825.000000
# mean    980.482677    10.053846   248.696130
# std     336.756618     5.515370   118.159627
# min       0.000000     0.000000     0.000000
# 25%     784.071354     5.000000   156.916498
# 50%     997.725134    10.000000   229.344557
# 75%    1208.512721    15.000000   324.867847
# max    1888.932537    19.000000   703.228418

# %%
# pandas indexing & selection - loc & iloc 
data={
    'Name':['Alice','Bob','Chalie','David'],
    'Age':[25,30,22,33],
    'City':['New York','Paris','London','Berlin'],
    'Salary':[70000,80000,90000,60000]
}
df= pd.DataFrame(data)
print("Original DataFrame:\n",df)
# Out:
# Original DataFrame:
#       Name  Age      City  Salary
# 0   Alice   25  New York   70000
# 1     Bob   30     Paris   80000
# 2  Chalie   22    London   90000
# 3   David   33    Berlin   60000

# %%
# lable-based selection (.loc)
subset_loc = df.loc[1:3,['Name','Salary']]
print("Subset with .loc: \n",subset_loc)
# Out:
# Subset with .loc:
#       Name  Salary
# 1     Bob   80000
# 2  Chalie   90000
# 3   David   60000

# %%
# integer_based selection (.iloc)
subset_iloc = df.iloc[0:2,1:3]
print("Subset with .iloc: \n",subset_iloc)
# Out:
# Subset with .iloc:
#     Age      City
# 0   25  New York
# 1   30     Paris

# %%
# Booleon filtering 
high_salary = df[df['Salary']>75000]
print("High salary filter: \n",high_salary)
# Out:
# High salary filter:
#       Name  Age    City  Salary
# 1     Bob   30   Paris   80000
# 2  Chalie   22  London   90000

# %%
# safe assignment using .loc
df.loc[df['Age']<30,'Salary']=65000
print("Low Age salary change: \n",df.loc[df['Age']<30,'Salary'])
# Out:
# Low Age salary change:
#  0    65000
# 2    65000
# Name: Salary, dtype: int64
