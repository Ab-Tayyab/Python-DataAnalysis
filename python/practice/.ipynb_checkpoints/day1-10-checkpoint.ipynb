# %%
# Day 1 Variables and data types

# %%
# What is a variable in Python? Write a statement that assigns the integer 42 to a variable named 'age'.
# a variable is a symbolic name that acts as a reference or pointer to an object stored in the computer's memory
age = 42
print(age)
# Out:
# 42

# %%
# What are the five basic built-in data types in Python? Give one example value for each.

# integer
a = 10
print(type(a))

# float
b = 3.14
print(type(b))

# string
c = "Abdullah"
print(type(c))

# Booleon
d = True
print(type(d))

# list
e = ['a',10,3.14,True]
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>

# %%
# Write Python code to create variables storing your name (str), age (int), height (float), and whether you are a student (bool)
name= "Abdullah Tayyab"
age = 26
height = 5.4
isStudent = False
print(f"My name is: {name}, i'm {age} year old. My height is {height} and is am i student: {isStudent} ")
# Out:
# My name is: Abdullah Tayyab, i'm 26 year old. My height is 5.4 and is am i student: False

# %%
# What is the difference between int and float in Python? Write an example of each.
# int is integer value but float is decimal value
n = 100
f=3.14
print("Integer: ",n," and float is: ",f)
# Out:
# Integer:  100  and float is:  3.14

# %%
# Use the type() function to print the data type of the following values: 10, 3.14, 'hello', True, None.
print(type(10))
print(type(3.14))
print(type('hello'))
print(type(True))
print(type(None))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %%
# What does dynamic typing mean in Python? Demonstrate by assigning an integer then a string to the same variable.
# Dynamic typing mean we can change variable value by assigning value again
n = 10
n="Hello"
print(n)
# Out:
# Hello

# %%
# Write Python code to swap the values of two variables x = 5 and y = 10 without using a third variable.
a = 40
b=5
print ("Before: ",a, " : ",b)
a = a-b
b = a+b
a = b-a
print ("After: ",a, " : ",b)

# or 
a = a^b
b = a^b
a = a^b
print ("Usig caret operator: ",a, " : ",b)
# Out:
# Before:  40  :  5
# After:  5  :  40
# Usig caret operator:  40  :  5

# %%
What is the difference between a single-quoted string and a double-quoted string in Python?
# The main difference between single (') and double (") quoted strings is that double quotes often allow for variable 
# interpolation (parsing variables) and escape sequences (e.g., \n for newline), while single quotes display the string literally as written.

str1 = "Abdullah"
str2 = 'Tayyab'
print(str1," : ",str2)
# Out:
# Object `Python` not found.
# Abdullah  :  Tayyab

# %%
 # Write Python code that creates a variable 'pi' with value 3.14159 and prints a message: 'The value of pi is 3.14159'.
pi = 3.1459
print("The value of pi is: ",pi)
# Out:
# The value of pi is:  3.1459

# %%
# What is None in Python? Write a variable 'result' set to None and check its type.
# It reperesent absence of value or null object 
n = None
print(type(n))
# Out:
# <class 'NoneType'>

# %%
# Day 2 Variables and data types

# %%
# What are naming rules for variables in Python? List three valid and three invalid variable names with reasons.

# Always Start with a Letter or an Underscore. Variable names must start with a letter or an underscore, like item_name or _price . ...
# Use Only Letters, Numbers, and Underscores. ...
# Be Aware of Case Sensitivity. ...
# Don't Use Python's Reserved Words.

_name = "Joe" # valid
print(_name," is valid")
age = 26 # valid
print(age," is valid")
num1 = 10 # valid
print(num1," is valid")

1num = 20 # invalid
print(1num," is not valid")
print = "joe" # invalid
print(print," is not valid")
num@ = 10 # invalid
print(num@," is not valid")
# Out:
#   Cell In[13], line 15
#     1num = 20 # invalid
#     ^
# SyntaxError: invalid decimal literal

# %%
# What is type casting? Convert the string '42' to an integer and the integer 7 to a float using built-in functions.
# change one variable type to another like sting to integer
strings = "42"
print("Before conversion: ", strings, type(strings))
print("Before conversion: ", int(strings), type(int(strings)))

num = 10
print("Before conversion: ", num, type(num))
print("Before conversion: ", float(num), type(float(num)))

# %%
# Write code to check if the variable x = 100 is of type int using isinstance().
x = 100
print(isinstance(x,int))

# %%
# . What is the difference between implicit and explicit type conversion? Give an example of each.
# implicit type conversion which compiler convert autometically to avoid loss of data like int to float
# explicit type conversion is which we convert menually

x = 10
y=5.5
print("implicit type conversion is: ",x," + ",y," = ",x+y)

strings = "42"
print("Explicit type conversion is: ",strings,type(strings)," after :" ,strings,type(int(strings)))

# %%
# Write a Python program that takes a number stored in a variable and prints whether it is
# positive, negative, or zero using only data-type knowledge (no conditionals).

a = 10
result = {1:"Positive",-1:"Negtive",0:"Zero"}
print(result[(a>0) - (a<0)])

# %%
# What are complex numbers in Python? Create a complex number 3+4j and print its real and imaginary parts.
# complex number is a combination of real and imaginary part 
num = 3+14j
print(type(num))
print("Real Number: ",num.real)
print("Imaginary part: ",num.imag)

# %%
# What is the difference between id() and type()? Use both on variables a = 5 and b = 5.
# id() show its memory location address
# and type() show its data type 
a = 5
b = 5
print(id(a))
print(type(b))

# %%
# Write code to create a multi-line string using triple quotes and print its length.
strings = """I'am Abdullah Tayyab
and struggling to improve AI skills"""
print(strings)
print("Length is: ",len(strings))

# %%
# Explain what happens when you write x = y = z = 0 in Python. What is the value and type of each variable?
x = y = z=10
print(x, type(x))
print(y, type(y))
print(z, type(z))

# %%
# What is the difference between mutable and immutable data types? Name two of each in Python.
# You can add, remove, or change elements without creating a new object.
print("Mutable...")
li = ["Hello",10]
print("First assign: ",li)
li[1] = 15
print("After re-assign: ",li)

dic = {"name":"Abdullah","Age":27}
print("First assign: ",dic)
dic["Age"] = 26
print("After re-assign: ",dic)

# These cannot be changed once created. Any modification results in a new object.
print("\nImmutable...")

x = 5
x = x+1
print(x) # new object created

tup = (1,2,3,4)
print("First assign: ",tup)
tup[1] = 5
print("After re-assign: ",tup)

# %%
# Day 3 Variables and data types

# %%
# What is the sys.maxsize value in Python, and how does Python handle integers larger than it?
# sys.maxsize is the largest positive integer a Python index-sized integer can have on your system. 
# It usually reflects the maximum size of containers like lists or strings.
# On a 64-bit system, it is typically: 9223372036854775807  # (2^63 - 1)
# On a 32-bit system, it is:2147483647  # (2^31 - 1)

import sys
print(sys.maxsize)

# 🔹 Does it limit Python integers?
# No—this is where Python is different from many other languages.
# Python integers (int) are unbounded, meaning:
# They can grow as large as your system’s memory allows.
# They are not limited by sys.maxsize.

# 🔹 How Python handles very large integers
# When numbers exceed typical fixed-size limits:
# Python automatically switches to using more memory.
# Internally, it represents integers using multiple machine words (arbitrary-precision arithmetic).

x = 9223372036854775807  # sys.maxsize on 64-bit
y = x + 1

print(y)
# No overflow occurs—Python just keeps going.

# %%
# Write code demonstrating the difference between == (equality) and is (identity) for small integers vs large integers

# In Python, == checks value equality, while is checks object identity (whether both variables point to the same object in memory).
# Small integers are often cached (interned), while large integers usually are not—this creates a visible difference.

# Small integers
a = 10
b = 10

print("Small integers:")
print("a == b:", a == b)  # True (same value)
print("a is b:", a is b)  # True (same object due to interning)

# Large integers
x = 1000
y = 1000

print("\nLarge integers:")
print("x == y:", x == y)  # True (same value)
print("x is y:", x is y)  # Usually False (different objects)

# Forcing creation of separate objects explicitly
m = int("1000")
n = int("1000")

print("\nLarge integers (explicit objects):")
print("m == n:", m == n)  # True
print("m is n:", m is n)  # False

# %%
# What is integer interning in Python? Write code to demonstrate when two variables share the same object in memory.

# Integer interning is an optimization where Python reuses existing integer objects instead of creating new ones.
# Python automatically interns (caches) small integers, typically in the range -5 to 256.
# When you assign variables within this range, they often point to the same memory object.
# For integers outside this range, Python usually creates separate objects.

# Small integers (interned)
a = 100
b = 100

print("Small integers:")
print("a == b:", a == b)  # True (same value)
print("a is b:", a is b)  # True (same object)

# Large integers (not always interned)
x = 1000
y = 1000

print("\nLarge integers:")
print("x == y:", x == y)  # True (same value)
print("x is y:", x is y)  # Usually False (different objects)

# Force separate objects
m = int("1000")
n = int("1000")

print("\nExplicitly created integers:")
print("m == n:", m == n)  # True
print("m is n:", m is n)  # False

# Checking memory addresses
print("\nMemory addresses:")
print("id(a):", id(a))
print("id(b):", id(b))
print("id(x):", id(x))
print("id(y):", id(y))
print("id(m):", id(m))
print("id(n):", id(n))

# %%
# Write a program that converts a temperature from Celsius to Fahrenheit using variables: C= 100.
c = 100
temp = c*(9/5)+32
print(temp)

# %%
# Explain the concept of variable scope (global vs local). Write an example showing both.
# local variable define inside function and cannot excess outside function
# global variable define outside function and excess every where

out = 10

def add():
    inside = 5
    print(out + inside)

add()
print(out + inside)

# %%
# What are constants in Python? How are they conventionally defined? Give an example.

# In Python, constants are variables whose values are intended not to change throughout the program.
# Important: Python does not enforce true constants (unlike some other languages). They are based on convention, not strict rules.

# 🔹 How are constants defined?
# By convention:
# Use UPPERCASE variable names
# Separate words with underscores (_)
# This signals to other programmers: “don’t change this value.”

PI = 10
print("Value of PI:", PI)
# You *can* change it, but you shouldn't
PI = 11  # discouraged
print("Modified PI:", PI)

# %%
# Write code that uses the bytes and bytearray types to store the string 'Python' in binary form.

# Original string
text = "Python"

# Convert to bytes (immutable binary data)
byte_data = bytes(text, "utf-8")
print("Bytes:", byte_data)

# Optional: demonstrate that bytes is immutable
byte_data[0] = ord('p')  # change 'P' to 'p'
print("Modified bytearray:", byte_data)

# Convert to bytearray (mutable binary data)
byte_array = bytearray(text, "utf-8")
print("Bytearray:", byte_array)

# Optional: demonstrate that bytearray is mutable
byte_array[0] = ord('p')  # change 'P' to 'p'
print("Modified bytearray:", byte_array)


# Explanation:
# bytes() creates an immutable sequence of bytes.
# bytearray() creates a mutable sequence of bytes.
# "utf-8" encoding converts the string into its binary representation.

# %%
# What is the difference between str(), repr(), and format()? Show examples of each.
# . str() — user-friendly representation
text = "Hello\nWorld"
print("use str: ",str(text))

# repr() — developer/debug representation
text = "Hello\nWorld"
print("use repr: ",repr(text))

# format() — customizable formatting
value = 3.14159
print("{:.2f}".format(value)) # use format()
value = 3.14159
print(f"{value:.2f}") # use f-sting
# Out:
# use str:  Hello
# World
# use repr:  'Hello\nWorld'
# 3.14
# 3.14

# %%
# Write a program that calculates the area of a circle given radius = 7, using the math module's pi constant.
import math
radius = 7
area = math.pi*radius*radius
print(area)
# Out:
# 153.93804002589985

# %%
# What are augmented assignment operators? Show examples of +=, -=, *=, /=, //=, **=, %= on a single variable.
# Augmented assignment operators are shorthand operators that combine an operation with assignment.
x= 10
x = x+1

# or
x+=1 # add and assign

x = x-1
# or
x -=1 # subtract and assign

x = x*2
# or
x *=2 # multiply and assign

x = x/2
# or
x /=2 # divide and assign

x = x//2
# or
x //=2 # floor divide and assign

x = x**2
# or
x**=2 # power and assign

x = x%2
# or
x %=2 # modulus and assign

# %%
# Day 4 conditional statements

# %%
# Write an if statement that checks whether a variable 'score' is greater than 50 and prints 'Pass' if true.
score = 510
if score>50:
    print("Pass")
# Out:
# Pass

# %%
# Write an if-else statement that prints 'Even' or 'Odd' based on the value of a variable 'number'.
n = 10
if n%2==0:
    print("Even: ",n)
else:
    print("Odd: ",n)
# Out:
# Even:  10

# %%
# What are comparison operators in Python? List all six with examples.
# Comparion operator are use to comapre two value
# == equal to 
# <= less than equal to
# >= greater than equal to
# != not equal to
# < less than
# > greater than

# %%
# Write an if-elif-else ladder that categorises a student's grade: A (>=90), B (>=80), C (>=70), D (>=60), F (below 60).
g = 80
if g>=90:
    print("A Grade")
elif g>=80:
    print("B Grade")
elif g>=70:
    print("C Grade")
elif g>=60:
    print("D Grade")
else:
    print("F Grade")
# Out:
# B Grade

# %%
# What is a nested if statement? Write an example that checks if a number is positive AND even.
# if condition whithin another if statement
n = 9
if n>0:
    if n%2==0:
        print("Even: ",n)
    else:
        print("Odd: ",n)
else:
    print("Number is not positive",n)
# Out:
# Odd:  9

# %%
# Write code using the 'in' operator to check whether a character is a vowel.
vowel = "aeiouAEIOU"
ch = "i"
if ch in vowel:
    print("Vowel: ",ch)
else:
    print("Not vowel: ",ch)
# Out:
# Vowel:  i

# %%
# What are logical operators (and, or, not) in Python? Write an example for each.
# logical operator compare two or more value and return as true or false
# AND: both true or false
# OR: one true and other true or false
# Not: reverse value, true to false and false to true
a = 10
b = 20
print("AND operator: ",a<b and a>0)
print("OR operator: ", a>b or a>0)

is_sunny = False
if not is_sunny:
    print("Take an umbrella!")
# Out:
# AND operator:  True
# OR operator:  True
# Take an umbrella!

# %%
# Write a Python program that checks if a year is a leap year using if-elif-else
y = 1900
if (y%4==0 and y%100!=0) or (y%400==0):
    print("Leap year: ",y)
else:
    print("Not a leap year: ",y)
# Out:
# Not a leap year:  1900

# %%
# What is short-circuit evaluation in Python? Demonstrate with 'and' and 'or'
# Short-circuit evaluation is a functional optimization in Python where the interpreter stops evaluating a boolean expression as soon as its final truth value can be determined. This technique, also known as lazy evaluation, improves performance and prevents errors by skipping unnecessary computations.
# The second part (1/0) is never evaluated because the first is False.
result = False and (1 / 0 > 1) 
print(result)  # Output: False (no ZeroDivisionError)
# The second part is skipped because the first is True.
result = True or (1 / 0 > 1)
print(result)  # Output: True (no ZeroDivisionError)
# Out:
# False
# True

# %%
# Write a program that takes three numbers and prints the largest using if-elif-else.
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))
if num1>num2 and num1>num3:
    print(num1," is greater.")
elif num2>num1 and num2>num3:
    print(num2," is greater.")
else:
    print(num3," is greater.")
# Out:
# Enter first number:  31
# Enter second number:  21
# Enter third number:  23
# 31  is greater.

# %%
# Day 5 Conditional statements

# %%
 # What is the ternary (conditional) expression in Python? Write one that assigns 'adult' or 'minor' to a variable based on age.
age = 18
result = "Adult" if age>18 else "Minor"
print(result," : ",age)
# Out:
# Minor  :  18

# %%
# What is 'truthiness' in Python? List five falsy values and explain why they evaluate to False.
# Truthiness in Python refers to how objects of any type are evaluated in a Boolean context, such as an if statement or a while loop. While only True and False are actual Booleans, Python implicitly converts other values into a Boolean state using the built-in bool() function. Values that evaluate to True are considered truthy, while those that evaluate to False are falsy.
# None: This represents the absence of a value. In a Boolean context, "nothingness" is treated as False. 
# 0 (Integer zero): Any numeric type with a value of zero—including 0, 0.0, or even complex 0j—is falsy.
# "" (Empty string): Strings are considered falsy when they contain no characters because their length is zero. 
# [] (Empty list): Similar to strings, empty sequences or collections (like lists, tuples, or sets) evaluate to False because they have no
# {} (Empty dictionary): Mappings that contain no key-value pairs are falsy. Python uses the len() method to determine if a collection is empty; if it returns 0, the object evaluates to False

# %%
# Write a program that validates a password: it must be at least 8 characters long, contain a digit, and contain an uppercase letter.
import re
password = input("Enter password")
upp = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
is_length = len(password)>=8
is_digit_have = bool(re.search(r"\d",password))
is_uppercase_have = bool(re.search(r"[A-Z]",password))
if is_length and is_digit_have and is_uppercase_have:
    print("Valid Password: ",password)
else:
    print("Not valid password: ",password)
# Out:
# Enter password abdullaH
# Not valid password:  abdullaH

# %%
# Demonstrate how to use the 'not in' operator in a conditional to check if an item is absent from a list.
# To use the not in operator in Python to check if an item is absent from a list
li = [1,2,3,4,5]
m = 6
if m not in li:
    print("Value not found: ")
else:
    print("Value found")
# Out:
# Value not found:

# %%
# Write code using chained comparisons (e.g., 10 < x < 20) to check if a number falls withina range.
n = 10
if 0<n<=10:
    print("Value found: Give range 1 to 10: ",n)
else:
    print("Value not found: Give range 1 to 10: ",n)
# Out:
# Value found: Give range 1 to 10:  10

# %%
# What is the match-case statement (Python 3.10+)? Write an example that maps day numbers to day names.
# Introduced in Python 3.10, the match-case statement is a feature known as Structural Pattern Matching. It functions similarly to the switch-case statements found in other languages but is more powerful, allowing you to match complex data structures and extract values directly.
value = 6
match value:
    case 1:
        print("Monday")
    case 2:
        print("Tuesday")
    case 3:
        print("Wednesday")
    case 4:
        print("Thursday")
    case 5:
        print("Friday")
    case 6:
        print("Saturday")
    case 7:
        print("Sunday")
    case _:
        print("Invalid Value!")
# Out:
# Saturday

# %%
# Write a program that checks if a given string is a palindrome using conditional logic
st = input("Enter string: ")
# rev = st[::-1]             # if wo dot initialize start and end index just add step -1 then it reverse string
rev = "".join(reversed(st))  # join methpd
if st==rev:
    print("Palindrome String: ", st," : ",rev)
else:
    print("Not a Palindrome String: ", st," : ",rev)
# Out:
# Enter string:  abdu
# Not a Palindrome String:  abdu  :  udba

# %%
# Explain how to combine multiple conditions using parentheses for readability. Give an example.
n = 22
if (n>0) and (n%2==0):
    print("Number is positive and even: ",n)
else:
    print("Number is not positive or even or number is zero: ",n)
# Out:
# Number is positive and even:  22

# %%
# Write a function-free script that solves the FizzBuzz problem for a single number using if-elif-else.
n = 45
if n%3==0 and n%5==0:
    print("FizzBuzz: ",n)
elif n%3==0:
    print("Fizz: ",n)
elif n%5==0:
    print("Buzz",n)
else:
    print("Oops!")
# Out:
# FizzBuzz:  45

# %%
# Write a program that classifies a triangle as Equilateral, Isosceles, or Scalene based on its three sides.
s1 = 10
s2 = 30
s3 = 20
if s1+s2>s3 or s1+s3>s2 or s2+s3>s1:
    if s1==s2==s3:
        print("Equilateral")
    elif s1==s2 or s1==s3 or s2==s3:
        print("Isoceles")
    else:
        print("Scalene")
else:
    print("Sum or two side must be greater then third")
# Out:
# Scalene
