# %%
# print name age city 
name = "Abdullah Tayyab"
age= 27
city= "Lahore"
print("Name: ",name)
print("Age: ",age)
print("City: ",city)
# Out:
# Name:  Abdullah Tayyab
# Age:  27
# City:  Lahore

# %%
# create variable and print in one line 
color = "Black"
number = "030000000"
food = "pulao"
print
